# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# При воспроизведении кода на локальной машине задайте plot_format = ''
plot_format = 'jpg'

# %% [markdown]
# # Исследование структуры данных
# ### Данные для исследования находятся [>>>ЗДЕСЬ<<<](https://drive.google.com/drive/folders/1Wvx8ewiY1Akng4aOa6v42SWPR2QtGU7f?usp=sharing)

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
df = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
# Создадим копию таблицы для дальнейших изменений
hh = df.copy()

# Функция нахождения образования
def get_edu(edu_string):
    res = None
    edu = edu_string.split(' ')[:2]
    if edu[0] == 'Высшее':
        res = 'высшее'
    elif edu[0] == 'Неоконченное' and edu[1] == 'высшее':
        res = 'неоконченное высшее'
    elif edu[0] == 'Среднее' and edu[1] == 'специальное':
        res = 'среднее специальное'
    elif edu[0] == 'Среднее' and edu[1] == 'образование':
        res = 'среднее'
    else:
        res = 'неизвестно'
    return res

# Создаем столбец
hh['Образование'] = hh['Образование и ВУЗ'].apply(get_edu)
# Даем ответ на вопрос
print(f'Соискателей со средним образованием: {round(hh[hh['Образование'] == 'среднее'].shape[0], 2)}')
# Удаляем старый столбец
hh = hh.drop('Образование и ВУЗ', axis=1)
# Out:
# Соискателей со средним образованием: 559

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# Создаем столбцы
hh['Пол'] = hh['Пол, возраст'].apply(lambda x: 'М' if x.split(',')[0].strip() == 'Мужчина' else 'Ж')
hh['Возраст'] = hh['Пол, возраст'].apply(lambda x: int(x.split(',')[1].strip().split(' ')[0]))

# Отвечаем на вопросы
print(f'Женских резюме, %: {round(hh[hh['Пол'] == 'Ж'].shape[0] * 100 / hh['Пол'].shape[0], 2)}')
print(f'Средний возраст кандидатов: {round(hh['Возраст'].mean(), 2)}')

# Удаляем старый столбец
hh = hh.drop('Пол, возраст', axis=1)
# Out:
# Женских резюме, %: 19.07
# Средний возраст кандидатов: 32.2

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def convert_to_num(str):
    '''
    Функция конвертации строки в число
    Возвращает float или False если переданная строка не конвертируется в число
    '''
    try:
        return float(str.strip())
    except ValueError:
        return False

# Функция возвращает кол-во месяцев опыта работы или NaN
def get_opyt(opyt):
    res = np.nan
    if type(opyt) == str and opyt != 'Не указано':
        try:
            opyt_array = opyt.split()
            if len(opyt_array) > 3:
                num_1 = convert_to_num(opyt_array[2])
                num_2 = convert_to_num(opyt_array[4]) if len(opyt_array) > 4 else False
                if num_1 and num_2:
                    res = num_1 * 12 + num_2
                else:
                    # Проверяем начинается ли 3-е слово на букву 'м'
                    m_after_num_1 = opyt_array[3].strip()[0] == 'м'
                    res = num_1 if m_after_num_1 else num_1 * 12
        except:
            print(f'Ошибка в обработке: {opyt}')
            return res
    return res

hh['Опыт работы (месяц)'] = hh['Опыт работы'].apply(lambda x: get_opyt(x))

# %%
# Отвечаем на вопросы
print(f'Медианный опыт работы, мес: {hh['Опыт работы (месяц)'].median()}')
# Удаляем старый столбец с опытом работы
hh = hh.drop('Опыт работы', axis=1)
# Out:
# Медианный опыт работы, мес: 100.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
hh.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %%
#ваш код здесь
import re
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]

# Возвращает 1 из 4 вариантов города соискателя
def get_gorod(gorod):
    if gorod in ['Москва', 'Санкт-Петербург']:
        res = gorod
    elif gorod in million_cities:
        res = 'город-миллионник'
    else:
        res = 'другие'
    return res

# Возвращает True если соискатель готов к переезду, иначе False
def is_move_ready(arr):
    res = False
    try:
        # Определяем итерируемый объект в зависимости от длинны входного массива
        iter = [arr[1], arr[2]] if len(arr) > 2 else [arr[1]]
        for i in iter:
            # Если в значении (строке) упоминается переезд, проверяем, не начинается ли он с "не готов"
            if re.search('перее', i):
                res = False if re.match('не готов', i) else True
    except:
        display(arr)
        return
    return res

def is_komand_ready(arr):
    res = False
    # Получаем значение командировки, если оно есть
    komand_item = arr[-1] if len(arr) > 2 else False
    # Если значение командировки задано и первое слово в нем не равно "не", присваиваем результат = True
    if komand_item and komand_item.split()[0].strip() != 'не':
        res = True
    return res

col = hh['Город, переезд, командировки']

# Создаем новые колонки в таблице согласно условиям (3 функциям выше)
hh['Город'] = col.apply(lambda x: get_gorod(x.split(' , ')[0].strip()))
hh['Готовность к переезду'] = col.apply(lambda x: is_move_ready(x.split(' , ')))
hh['Готовность к командировкам'] = col.apply(lambda x: is_komand_ready(x.split(' , ')))

# %%
# Отвечаем на вопросы
in_spb = round(hh[hh['Город'] == 'Санкт-Петербург'].shape[0] * 100 / hh.shape[0])
print(f'Сколько процентов соискателей живут в Санкт-Петербурге? ОТВЕТ: {in_spb}%')
p_and_k = round(hh[hh['Готовность к переезду'] & hh['Готовность к командировкам']].shape[0] * 100 / hh.shape[0])
print(f'Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? ОТВЕТ: {p_and_k}%')

# Удаляем ненужный столбец
hh = hh.drop('Город, переезд, командировки', axis=1)
# Out:
# Сколько процентов соискателей живут в Санкт-Петербурге? ОТВЕТ: 11%
# Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? ОТВЕТ: 32%

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Функция возвращает список уникальных значений
def prepare_unique_list(arr, list_to_prepare):
    for i in arr:
        i = i.strip()
        if i not in list_to_prepare:
            list_to_prepare.append(i)

# Получим список вариантов Занятости и графика
zanyatost_list, grafik_list = [], []
hh['Занятость'].apply(lambda x: prepare_unique_list(x.split(','), zanyatost_list))
hh['График'].apply(lambda x: prepare_unique_list(x.split(','), grafik_list))

# Добавим типы занятости со значениями True/False в таблицу (One Hot Encoder)
for i in zanyatost_list:
    hh[i] = hh['Занятость'].apply(lambda x: True if i in x.split(', ') else False)

#  Добавим типы Графика со значениями True/False в таблицу (One Hot Encoder)
for i in grafik_list:
    hh[i] = hh['График'].apply(lambda x: True if i in x.split(', ') else False)

# %%
# Ответы на вопросы
print('Сколько людей ищут проектную работу и волонтёрство (в обоих столбцах стоит True)?')
print(f'Ответ: {hh[hh['проектная работа'] & hh['волонтерство']].shape[0]}')

print('Сколько людей хотят работать вахтовым методом и с гибким графиком (в обоих столбцах стоит True)?')
print(f'Ответ: {hh[hh['вахтовый метод'] & hh['гибкий график']].shape[0]}')

# Удалим Занятость и График из таблицы
hh = hh.drop(['Занятость', 'График'], axis=1)
# Out:
# Сколько людей ищут проектную работу и волонтёрство (в обоих столбцах стоит True)?
# Ответ: 436
# Сколько людей хотят работать вахтовым методом и с гибким графиком (в обоих столбцах стоит True)?
# Ответ: 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# Подготовим таблицу с обменными курсами currency к RUB
rates = pd.read_csv('data/ExchangeRates.csv')
rates['date'] = pd.to_datetime(rates['date'], dayfirst=True, format='%d/%m/%y').dt.date
rates['rate'] = rates['close'] / rates['proportion']
rates = rates.drop(['per', 'time', 'vol', 'close', 'proportion'], axis=1)

# Посмотрим результат
# display(rates)

# Подготовим датафрейм с зарплатами и валютами
res = pd.DataFrame([])
res['val'] = hh['ЗП'].apply(lambda x: convert_to_num(x.split()[0]))
res['currency'] = hh['ЗП'].apply(lambda x: x.split()[1])
res['date'] = pd.to_datetime(hh['Обновление резюме'], dayfirst=True).dt.date

# Получим список вариантов валют из таблицы, чтобы видеть как они пишутся
cur_list = []
prepare_unique_list(res['currency'], cur_list)
# cur_list = ['руб.', 'бел.руб.', 'KZT', 'EUR', 'USD', 'грн.', 'сум', 'KGS', 'AZN']

# Переименуем нестандартно именованные валюты
def rename_currency(currency):
    if currency == 'руб.':
        return 'RUB'
    elif currency == 'бел.руб.':
        return 'BYN'
    elif currency == 'грн.':
        return 'UAH'
    elif currency == 'сум':
        return 'UZS'
    else:
        return currency

res['currency'] = res['currency'].apply(lambda x: rename_currency(x))

def get_rate(currency, date, rates):
    filtered = rates[(rates['currency'] == currency) & (rates['date'] == date)]
    if not filtered.empty:
        return filtered['rate'].iloc[0]
    return 1  # Если курс не найден, возвращаем 1 как значение по умолчанию


res['ЗП (руб)'] = res.apply(
    lambda row: row['val'] if row['currency'] == 'RUB' else (row['val'] * get_rate(row['currency'], row['date'], rates)),
    axis=1
)

hh['ЗП (руб)'] = res['ЗП (руб)']
hh.head()
# Out:
# /var/folders/4l/ky4__ny56_vb8bpdlg447zym0000gn/T/ipykernel_96054/4085793301.py:3: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# ...

# %%
# Ответим на вопрос
print(f'Мединная ЗП в тыс. руб = {int(hh['ЗП (руб)'].median() / 1000)}')

# Удалим ненужный столбец
hh = hh.drop('ЗП', axis=1)

# Выведем инфо о итоговой таблице
hh.info()
# Out:
# Мединная ЗП в тыс. руб = 59
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Устанавливаем kaleido для экспорта диаграмм в jpg формат
# %pip install -U kaleido

# %%
# Построим гистограмму и коробчатую диаграмму
import plotly.express as px

px.histogram(
    hh['Возраст'],
    labels={'value': 'Возраст', 'variable': 'Признак'},
    title='Гистограмма распределения возраста'
).show(plot_format)
px.box(
    x=hh['Возраст'],
    labels={'x': 'Возраст'},
    title='Коробчатая диаграмма распределения возраста'
).show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Мода возрастов = 30
# 2. Диапазон указанных возрастов 14-100 - предельные значения признака
# 3. Возраст большинства соискателей находится в диапазоне 14-49 лет.
# 4. Явной аномалией в признаке "Возраст" считается значение 100. До таких лет доживают-то редко, не то что на HH работу искать. Скорее всего это намеренно введенные некорректные значения.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Строим гистограмму и ящик с усами рядом
px.histogram(
    hh['Опыт работы (месяц)'],
    labels={'value': 'Опыт работы (месяц)', 'variable': 'Признак'},
    title='Гистограмма распределения опыта'
).show(plot_format)

px.box(
    x=hh['Опыт работы (месяц)'],
    labels={'x': 'Опыт работы (месяц)'},
    title='Коробчатая диаграмма распределения опыта'
).show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Мода опыта работы в диапазоне 80-84 мес.
# 2. Предельные значения признака 1-1188 мес
# 3. Возраст большинства соискателей находится в диапазоне 1-299 мес.
# 4. Явной аномалией в признаке "Опыт работы (месяц)" считается значение 1188 мес. Это 99 лет опыта работы, к тому же цифры в числе стоят парами, это явно фиктивный набор с клавиатуры. Также под сомнением опыт 622 мес. и больше (более 52 лет) - тут нужно смотреть остальные данные кандидата.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построим ящик с усами
px.box(
    x=hh['ЗП (руб)'],
    labels={'x': 'ЗП (руб)'},
    title='Коробчатая диаграмма распределения ЗП'
).show(plot_format)

# Строим гистограмму, исключая ЗП выше 1млн, чтобы увидеть моду, которая находится сильно ближе к началу
px.histogram(
    hh[hh['ЗП (руб)'] < 1000000]['ЗП (руб)'],
    labels={'value': 'ЗП (руб)', 'variable': 'Признак'},
    title='Гистограмма распределения ЗП'
).show(plot_format)

# Посмотрим, кто хочет ЗП выше 1 млн
hh[hh['ЗП (руб)'] > 1000000].sort_values(by='ЗП (руб)')
# Out:
#                                Ищет работу на должность:  \
# 41924                                    Project manager
# 43134                                   Chief AI Officer
# 28253  Руководитель IT проектов, Роботизация, Автомат...
# 39191                                   Специалист по IT
# 6931   Программирование, Разработка или Системный адм...
#
#                          Последнее/нынешнее место работы  \
# 41924                                      Тинькофф Банк
# 43134  Finnish Russian Univeristy Cooperation in Tele...
# 28253                                   HAMSTER ROBOTICS
# 39191                                          ТОО "AMS"
# 6931                                Евразийский банк, АО
#
#                             Последняя/нынешняя должность Обновление резюме  \
# 41924            Технолог автоматизации бизнес-процессов  22.04.2019 18:48
# 43134         Project Manager in Multimedia Technologies  25.10.2018 02:49
# ...

# %% [markdown]
# ### Выводы:
# 1. Мода ЗП в диапазоне 50-52.000 руб.
# 2. Предельные значения признака от 1 до 24.3 млн.руб.
# 3. ЗП большинства соискателей находится в диапазоне 1-180900 руб.
# 4. 5 кандидатов хотят ЗП выше 1 млн. руб. Двое из них больше похожи на выбросы, чем остальные. Которые хотят ЗП выше 7 млн, при этом работая сейчас не на топ-менеджерских позициях, а вполне рядовыми специалистами. Первый из них не имеет высшего образования и совсем небольшой опыт работы (98 мес) для такой ЗП. Второй хочет ЗП выше 24млн руб, что не особо реалистично даже для разработчиков крупных американских IT-компаний таких как Амозон или FB.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# Построим диаграмму зависимости медианной ожидаемой ЗП от уровня образования
px.bar(
    hh.groupby(by='Образование')['ЗП (руб)'].median(),
    labels={'value': 'Медианная ЗП', 'variable': 'Признак'},
    title='Зависимость медианной желаемой ЗП от образования'
).show(plot_format)

# Построим диаграмму числа кандидатов по уровню образования
px.bar(
    hh.groupby(by='Образование')['Образование'].count(),
    labels={'value': 'Число кандидатов', 'index': 'Образование', 'variable': 'Признак'},
    title='Распределение числа кандидатов по образованию'
).show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Наибольшие ожидания по ЗП у кандидатов с высшим образованием. Наименьшие у кандидатов со средним или средне-специальным.
# 2. Признак образования важен при прогнозировании ЗП. В большинстве случаев люди с высшим образованием способны выполнять более сложные интеллектуальные задачи, и хотят за это больше денег.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Выделим тех, у кого ожидаемая ЗП ниже 1 млн
lower_lemon = hh[hh['ЗП (руб)'] < 10**6]
# Построим диаграмму зависимости медианной ожидаемой ЗП от города кандидата
px.box(
    x = lower_lemon['ЗП (руб)'],
    y = lower_lemon['Город'],
    labels={'x': 'ЗП (руб)', 'y': 'Город'},
    title='Зависимость желаемой ЗП от города'
).show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Выше всего медианный уровень ЗП в Москве (85к), на в СПб же он равен значению 25 персентиля московского (60к).
# 2. Признак города важен при прогнозировании ЗП в столицах (МСК, СПб). Для остальных городов можно им принебречь, т.к. распределение ЗП похоже.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
data = pd.DataFrame(hh[['ЗП (руб)', 'Готовность к переезду', 'Готовность к командировкам']])

data["Переезд"] = data["Готовность к переезду"].replace({True: "Готов", False: "Не готов"})
data["Командировки"] = data["Готовность к командировкам"].replace({True: "Готов", False: "Не готов"})

# Группировка и расчет медианы
median_salary = (
    data.groupby(["Переезд", "Командировки"])["ЗП (руб)"]
    .median()
    .reset_index()
)

# Создаем столбчатую диаграмму
fig = px.bar(
    median_salary,
    x="Переезд",
    y="ЗП (руб)",
    color="Командировки",
    barmode="group",
    title="Зависимость зарплаты от готовности к переезду и командировкам",
    # labels={"Готовность к переезду": "Переезд", "Готовность к командировкам": "Командировки", "ЗП (руб)": "Медианная ЗП"}
)

fig.show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Наибольшее влияние на медианную ЗП оказывает готовность к командировкам. Готов к командировкам - можешь просить больше денег. В меньшей степени влияет готовность к переезду.
# 2. Больше всего ЗП ожидается у кандидатов с наибольшей мобильностью.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
import plotly.graph_objects as go

# Готовим сводную таблицу
zp_age_edu = pd.pivot_table(
    data = hh,
    index='Возраст',
    columns='Образование',
    values='ЗП (руб)',
    aggfunc='median'
)

# Настраиваем тепловую карту и данные на ней
fig = go.Figure(data=go.Heatmap(
    z=zp_age_edu,
    x=zp_age_edu.columns,
    y=zp_age_edu.index,
    colorbar=dict(title="Медианная ЗП")  # Подпись к шкале z
))

# Настройка подписей осей
fig.update_layout(
    title="Зависимость медианной ЗП от возраста и образования",
    xaxis_title="Образование",
    yaxis_title="Возраст",
)

# Отображаем тепловую карту
fig.show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Наблюдается рост ожидаемой ЗП как с увеличением возраста, так и повышением уровня образования.
# 2. Круче всего карьерный рост (рост ЗП с ростом опыта = возрастом) наблюдается у кандидатов с высшим образованием

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
import plotly.graph_objects as px

fig = go.Figure(data=[px.Scatter( 
    x = hh['Возраст'],
    y = hh['Опыт работы (месяц)'] / 12,
    mode = 'markers',
    name = 'Кандидат'
    )
])

# Добавление линии через Scatter
fig.add_trace(go.Scatter(
    x=[0, 100],  # Координаты X для линии
    y=[0, 100],  # Координаты Y для линии
    mode="lines",  # Только линия
    line=dict(color="red", width=2),  # Настройки линии
    name="Опыт = возрасту"  # Название линии
))

# Настройка подписей осей
fig.update_layout(
    title="Зависимость опыта работы (лет) от возраста",
    yaxis_title="Опыт работы",
    xaxis_title="Возраст"
)

fig.show(plot_format)

# Также найдем, сколько кандидатов имеют опыт > возраста
print(f'Число кандидатов с опытом больше возраста: {hh[hh['Возраст'] < hh['Опыт работы (месяц)']/12].shape[0]}')
# Out:
# Число кандидатов с опытом больше возраста: 7

# %% [markdown]
# ### Выводы:
# 1. Красная линия "возраст = опыт" находится примерно на 20 лет выше облака точек. Это нормально, поскольку несовершеннолетние обычно не работают, а учатся. И реальный опыт начинают получать уже после 18-20 лет. После колледжа или института (или в студенческие годы).
# 2. Чем выше точка кандидата от общего облака, тем раньше кандидат начал получать свой трудовой опыт. В целом, подобные точки, где разница между возрастом и опытом составляет меньше 10 лет, можно считать выбросами.
# 3. Точки выше красной линии означают, что опыт работы кандидата (в годах) превышает количество прожитых им лет. Это может свидетельствовать об ошибках (случайных или намеренных) в заполнении кандидатом профиля. И можно считать выбросами.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
import seaborn as sns
# Построим матрицу корреляций между признаками
corr = hh.corr(numeric_only=True).round(2)
# Для удобного анализа матрицы корреляции добавим цвет:
# Создание heatmap с отображением значений корреляции
plt.figure(figsize=(10, 8))
sns.heatmap(
    corr,
    annot=True,            # Показывает значения на карте
    fmt=".2f",             # Округление до 2 знаков
    cmap="coolwarm",       # Цветовая схема
    linewidths=0.5,        # Разделение между ячейками
    cbar_kws={"label": "Коэффициент корреляции"}  # Подпись цветовой шкалы
)

plt.title("Матрица корреляций")
plt.show()

# Посмотрим на зависимость медианной ЗП от пола и возраста кандидатов из МСК с высшим образованием
import plotly.graph_objects as go

# Готовим сводную таблицу
zp_age_edu = pd.pivot_table(
    data = hh[(hh['Город'] == 'Москва') & (hh['Образование'] == 'высшее')],
    index='Возраст',
    columns='Пол',
    values='ЗП (руб)',
    aggfunc='median'
)

# Настраиваем тепловую карту и данные на ней
fig = go.Figure(data=go.Heatmap(
    z=zp_age_edu,
    x=zp_age_edu.columns,
    y=zp_age_edu.index,
    colorbar=dict(title="Медианная ЗП")  # Подпись к шкале z
))

# Настройка подписей осей
fig.update_layout(
    title="Зависимость медианной ЗП москвичей с высшим образованием от возраста и пола",
    xaxis_title="Пол",
    yaxis_title="Возраст",
)

# Отображаем тепловую карту
fig.show(plot_format)

# %% [markdown]
# ### Выводы:
# 1. Наблюдается сильная положительная корреляция между возрастом и опытом работы, что логично, ведь чем больше возраст, тем больше человек приобретает рабочего опыта.
#
# 2. Также наблюдается средняя положительная корреляция между занятостью и графиком работы. Готовые только на частичную занятость чаще указыват гибкий график работы и удаленную или проектную работу. А готовые к полной занятости чаще указывают полный день в качестве графика работы. Указывающие гибкий график, также часто указывают сменный график и обычно ищут удаленный формат работы.
#
# 3. По диаграмме зависимости медианной ЗП от пола и возраста (для кандидатов с высшим образованием в Москве) видно, что:
#    + Мужчины начинают работать раньше и заканчивают трудовую деятельность позже. Если ищущие работу женщины после 60 - редкость, то среди мужчин старше 60 наблюдается резкий рост требования к уровню ЗП. Возможно, это можно объяснить большим опытом и занятием руководящих позиций.
#    + Как среди женщин, так и среди мужчин есть кандидаты, указавшие наличие высшего образования в возрасте до 20 лет:)
#    + Зарплатные ожидания мужчин выше, чем у женщин

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
# Предварительно преобразуем столбец "Обновление резюме", удалив время и оставив только ГГГГ-ММ-ДД
hh['Обновление резюме'] = pd.to_datetime(hh['Обновление резюме'], dayfirst=True).dt.date
print(f'В таблице {hh.duplicated(keep='first').sum()} полных дублей')

# удалим полные дубли
print(f'Число строк до удаления дублей: {hh.shape[0]}')
hh = hh.drop_duplicates()
print(f'Число строк после удаления дублей: {hh.shape[0]}')
# Out:
# В таблице 161 полных дублей
# Число строк до удаления дублей: 44744
# Число строк после удаления дублей: 44583

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Посчитаем пропуски и выведем ненулевые
nulls = hh.isnull().sum()
nulls[nulls > 0]
# Out:
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Опыт работы (месяц)                168
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удалим строки с пропусками в 2 полях
hh.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'], how='all', inplace=True)
hh['Опыт работы (месяц)'] = hh['Опыт работы (месяц)'].fillna(hh['Опыт работы (месяц)'].median())

# Выведем результирующее среднее значения опыта работы после заполнения пропусков
print(f'Среднее значение опыта: {round(hh['Опыт работы (месяц)'].mean())}')
# Out:
# Среднее значение опыта: 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Определим индексы удаляемых строк
lets_drop = hh[(hh['ЗП (руб)'] > 10**6) | (hh['ЗП (руб)'] < 1000)].index
print(f'Нужно удалить {lets_drop.shape[0]} строк')

# Удалим найденные строки по их индексам
print(f'Строк до удаления: {hh.shape[0]}')
hh.drop(index=lets_drop, inplace=True)
print(f'Строк после удаления: {hh.shape[0]}')
# Out:
# Нужно удалить 89 строк
# Строк до удаления: 44582
# Строк после удаления: 44493

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Определим индексы удаляемых строк
lets_drop = hh[hh['Опыт работы (месяц)']/12 > hh['Возраст']].index
print(f'Нужно удалить {lets_drop.shape[0]} строк')

# Удалим найденные строки по их индексам
print(f'Строк до удаления: {hh.shape[0]}')
hh.drop(index=lets_drop, inplace=True)
print(f'Строк после удаления: {hh.shape[0]}')
# Out:
# Нужно удалить 7 строк
# Строк до удаления: 44493
# Строк после удаления: 44486

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
import seaborn as sns

# Функция определения выбросов по методу 3 сигм
def outliers_z_score(data, feature, left = 3, right = 3, log_scale=False):
    ''' Функция определения выбросов по методу 3 сигм
    data: pandas.DataFrame - исходные данные
    feature: string - параметр, с которым работаем
    left: int - левая граница интервала (кратная числу сигм)
    right: int - правая граница интервала (кратная числу сигм)
    log_scale: bool - требуется ли логарифмировать параметр
    '''
    if log_scale:
        x = np.log(data[feature]+1)
    else:
        x = data[feature]
    mu = x.mean()
    sigma = x.std()
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    return outliers, cleaned


# Построим логарифмическое распределение возраста
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = np.log(hh['Возраст'])
histplot = sns.histplot(log_age, bins=30, ax=ax)
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Логарифмическое распределение возраста с правосторонней ассимметрией')

# Определим выбросы по методу z-отклонения с послаблением на 1 сигму в правую сторону
outliers, cleaned = outliers_z_score(data=hh, feature='Возраст', right=4, log_scale=True)
outliers
# Out:
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность Обновление резюме        Авто  \
# 31137  Менеджер по работе с клиентами        2019-04-06  Не указано
# 32950                  Тестировщик ПО        2019-04-09  Не указано
# 33654            Frontend-разработчик        2019-04-19  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)            Город  \
# 31137              среднее   М       15                  2.0  Санкт-Петербург
# 32950  среднее специальное   М       15                  3.0           другие
# 33654  среднее специальное   М      100                 30.0  Санкт-Петербург
#
#        ...  проектная работа  полная занятость  стажировка  волонтерство  \
# ...

# %% [markdown]
# ### Выводы:
# 1. Наблюдается правосторонняя ассиметрия (среднее > моды) возраста.
# 2. С помощью метода 3 сигм (с послаблением вправо на 1 сигму) нашли 3 выброса с возрастами кандидатов 15 и 100 лет
